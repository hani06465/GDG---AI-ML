# %% [markdown]
# <a href="https://colab.research.google.com/github/hani06465/GDG_AI-ML_2025-26/blob/main/SLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba48bd46-0d16-43aa-ad80-549162d2b21c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba48bd46-0d16-43aa-ad80-549162d2b21c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# this helps us upload my housing.csv to google colab so i can use the data set given

# %%
import pandas as pd

df = pd.read_csv("Housing.csv")
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
import seaborn as sns

# %%
sns.pairplot(df,kind='scatter',plot_kws={'alpha':0.4})

# %% [markdown]
# here identfiying the one independent varible that affects most is dificult because the pictures are almost the same, so we need numbers so let's find the coeffinent of each..

# %%
from sklearn.model_selection import train_test_split
x=df[['area','bedrooms','bathrooms','stories','parking']]
y=df['price']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
lm.coef_
# Out:
# array([3.29285878e+02, 1.61077479e+05, 1.19412059e+06, 4.72530548e+05,
#        3.95480372e+05])

# %% [markdown]
# this gives me each coeefficent for each independent variable in relation to the dependent variable so i can now which coefficient most affect the price so i can do based on that and based on the above the best is "**stories**,  and the linera regression of this looks like this ..

# %%
import seaborn as sns
sns.jointplot(x="stories", y="price",data=df,alpha=0.5)

# %% [markdown]
# so next let's train our model based on this data.

# %%
x=df[['stories']]
y=df['price']
from sklearn.model_selection import train_test_split


X = df[['stories']]
y = df['price']


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)


from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, y_train)

print("Intercept:", lm.intercept_)
print("Coefficient for stories:", lm.coef_[0])
# Out:
# Intercept: 3298112.520224135
# Coefficient for stories: 821643.4753970612
